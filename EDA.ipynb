# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data 
df = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx')
# columns_name
df.columns = ['Relative Compactness','Surface Area',' Wall Area','Roof Area','Overall Height','Orientation','Glazing Area','Glazing Area Distribution','Heating Load','Cooling Load']
df.head()  # First five rows
# Out:
#    Relative Compactness  Surface Area   Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5       294.0     110.25             7.0
# 1                  0.98         514.5       294.0     110.25             7.0
# 2                  0.98         514.5       294.0     110.25             7.0
# 3                  0.98         514.5       294.0     110.25             7.0
# 4                  0.90         563.5       318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling Load
# 0         21.33
# 1         21.33
# 2         21.33
# ...

# %%
# Shape of data
df.shape
# Out:
# (768, 10)

# %% [markdown]
# Number of Rows 768
# Number of Columns 10

# %%
# Missing Values
df.isnull().sum()
# Out:
# Relative Compactness         0
# Surface Area                 0
#  Wall Area                   0
# Roof Area                    0
# Overall Height               0
# Orientation                  0
# Glazing Area                 0
# Glazing Area Distribution    0
# Heating Load                 0
# Cooling Load                 0
# dtype: int64

# %% [markdown]
# No missing value in dataset

# %%
# Duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No Duplicated value in dataset

# %%
# information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative Compactness       768 non-null    float64
#  1   Surface Area               768 non-null    float64
#  2    Wall Area                 768 non-null    float64
#  3   Roof Area                  768 non-null    float64
#  4   Overall Height             768 non-null    float64
#  5   Orientation                768 non-null    int64
#  6   Glazing Area               768 non-null    float64
#  7   Glazing Area Distribution  768 non-null    int64
#  8   Heating Load               768 non-null    float64
#  9   Cooling Load               768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
# Statistical description
df.describe().T
# Out:
#                            count        mean        std     min       25%  \
# Relative Compactness       768.0    0.764167   0.105777    0.62    0.6825
# Surface Area               768.0  671.708333  88.086116  514.50  606.3750
#  Wall Area                 768.0  318.500000  43.626481  245.00  294.0000
# Roof Area                  768.0  176.604167  45.165950  110.25  140.8750
# Overall Height             768.0    5.250000   1.751140    3.50    3.5000
# Orientation                768.0    3.500000   1.118763    2.00    2.7500
# Glazing Area               768.0    0.234375   0.133221    0.00    0.1000
# Glazing Area Distribution  768.0    2.812500   1.550960    0.00    1.7500
# Heating Load               768.0   22.307195  10.090204    6.01   12.9925
# Cooling Load               768.0   24.587760   9.513306   10.90   15.6200
#
#                               50%       75%     max
# Relative Compactness         0.75    0.8300    0.98
# ...

# %%
# Corelation
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='viridis', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Relative Compactness and Surface Area are highly negative corelated
#
# Roof Area and Overall Heoght are highly negative corelated
#
# Heating load and Cooling load are highly positive corelated

# %%
# Variance Inflation Factor (VIF)
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = df[['Relative Compactness', 'Surface Area', ' Wall Area', 'Roof Area',
       'Overall Height', 'Orientation', 'Glazing Area',
       'Glazing Area Distribution', 'Heating Load', 'Cooling Load']]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Predictor"] = X.columns
print(vif)
# Out:
#    VIF Factor                  Predictor
# 0  196.663861       Relative Compactness
# 1         inf               Surface Area
# 2         inf                  Wall Area
# 3         inf                  Roof Area
# 4  239.849628             Overall Height
# 5   10.871550                Orientation
# 6    7.746600               Glazing Area
# 7    4.597785  Glazing Area Distribution
# 8  190.328677               Heating Load
# 9  184.860451               Cooling Load
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
#  Surface Area, Wall Area, and Roof Area have infinite VIF values
#
#  Relative Compactness and Overall Height also have relatively high VIF values

# %%
df.hist(figsize=(20,15))
plt.show()

# %%
sns.pairplot(df)
